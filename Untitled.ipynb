# %%
# %%bash
# cd gopher
# dx upload run_qc_chr1_22.sh -p --path /code/gopher/ --brief
# dx upload simulate_phenotypes.py -p --path /code/gopher/ --brief
# Out:
# bash: line 1: cd: gopher: No such file or directory
# file-J3zxVvQJGqyXq2pBbp650Kv8
# file-J3zxVvjJGqyYxp371J2Gy5Z0
